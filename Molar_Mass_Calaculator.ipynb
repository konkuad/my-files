# %% [markdown]
# <a href="https://colab.research.google.com/github/konkuad/my-files/blob/master/Molar_Mass_Calaculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
z = 0
while z == 0:
  def removebrackets(x):
    brackets = 0
    LastO = 0
    FirstC = len(x)
    for i in range(0,len(x)):
      if x[i] == "(":
        LastO = i
        brackets = brackets+1
    for i in range(0,len(x)):
      if x[i] == ")":
        brackets = brackets+1
        if i < FirstC:
          FirstC = i
        else:
          FirstC = FirstC
    if brackets != 0:
      Weight = int(x[FirstC+1])
      inside = x[LastO+1:FirstC]
      if FirstC + 1 == len(x)-1:
        x = x[0:LastO]+Weight*inside
      else:
        x = x[0:LastO]+Weight*inside+x[FirstC+2:len(x)]
    return(x)
  print("------------------------")
  element = input("Input your formula : ")
  element = removebrackets(element)
  Capital = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
  lower = "abcdefghijklmnopqrstuvwxyz"
  number = "0123456789"
  def iscapital(x):
    a = 0
    for i in range(0,len(Capital)):
      if x == Capital[i]:
        a = a+1
    if a == 0:
      return(0)
    else:
      return(1)
  def islower(x):
    a = 0
    for i in range(0,len(lower)):
      if x == lower[i]:
        a = a+1
    if a == 0:
      return(0)
    else:
      return(1)
  def isnumber(x):
    a = 0
    for i in range(0,len(number)):
      if x == number[i]:
        a = a+1
    if a == 0:
      return(0)
    else:
      return(1)
  b = []
  p = 0
  for i in range(0,len(element)):
    if iscapital(element[i]) == 1 :
      p = p+1
      k = ""
      k = k+element[i]
      j = i+1
      if j != len(element):
        while isnumber(element[j])==0 and iscapital(element[j])==0:
          k = k+element[j]
          j = j+1
          if j == len(element):
            break
      if j != len(element):
        while iscapital(element[j])==0:
          k = k+element[j]
          j = j+1
          if j == len(element):
            break
      b.append(k)
  def e2mw(x):
    if x == "H":
      return(1.0079)
    if x == "He":
      return(4.0026)
    if x == "Li":
      return(6.941)
    if x == "Be":
      return(9.0122)
    if x == "B":
      return(10.811)
    if x == "C":
      return(12.0107)
    if x == "N":
      return(14.0067)
    if x == "O":
      return(15.9994)
    if x == "F":
      return(18.9984)
    if x == "Ne":
      return(20.1797)
    if x == "Na":
      return(22.9897)
    if x == "Mg":
      return(24.305)
    if x == "Al":
      return(26.9815)
    if x == "Si":
      return(28.0855)
    if x == "P":
      return(30.9738)
    if x == "S":
      return(32.065)
    if x == "N":
      return(14.0067)
    if x == "Cl":
      return(35.453)
    if x == "Ar":
      return(39.948)
    if x == "K":
      return(39.0983)
    if x == "Ca":
      return(40.078)
    if x == "Sc":
      return(44.9559)
    if x == "Ti":
      return(50.9415)
    if x == "V":
      return(51.9961)
    if x == "Mn":
      return(54.938)
    if x == "Fe":
      return(55.845)
    if x == "Co":
      return(58.9332)
    if x == "Ni":
      return(58.6934)
    if x == "Cu":
      return(63.546)
    if x == "Zn":
      return(65.39)
    if x == "Ga":
      return(69.723)
    if x == "Ge":
      return(72.64)
    if x == "As":
      return(74.9216)
    if x == "Se":
      return(78.96)
    if x == "Br":
      return(79.904)
    if x == "Kr":
      return(83.8)
    if x == "Rb":
      return(85.4678)
    if x == "Sr":
      return(87.62)
    if x == "Y":
      return(88.9059)
    if x == "Zr":
      return(91.224)
    if x == "Nb":
      return(92.9064)
    if x == "Mo":
      return(95.94)
    else:
      return(0)
  mw = 0
  t = 1
  for i in range(0,len(b)):
    c = b[i]
    d = ""
    e = ""
    for j in range(0,len(c)):
      if isnumber(c[j])==1:
        e = e+c[j]
      elif isnumber(c[j])==0:
        d = d+c[j]
    f = e2mw(d)
    if f == 0:
      t = 0
    if e == "":
      g = 1
    else:
      g = int(e)
    mw = mw+f*g
  if t == 0 or p == 0:
    print("not an element you idiot")
    print("------------------------")
  else:
    print("Molecular mass is ",mw)
# Out:
# ------------------------
